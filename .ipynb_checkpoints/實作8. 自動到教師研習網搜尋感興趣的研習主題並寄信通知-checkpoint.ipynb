# %% [markdown]
# # 自動到 "教師研習網查詢有興趣的研習"
#
# 由於教師研習網並沒有提供過濾有興趣的研習的通知，每次都通知一大堆不會參加的研習，到最後就不想看了。
#
# 我們利用瀏覽器爬蟲來完成這個任務吧。讓自己更輕鬆地獲知研習訊息。

# %% [markdown]
# # 首先安裝必要的套件

# %% [markdown]
# ## 安裝 selenium
#
#     selenium 是一個自動測試工具

# %%
# !pip install selenium
# Out:
# Collecting selenium
#   Downloading https://files.pythonhosted.org/packages/b0/c9/52390baa8d6b65c3e3b89f522c3a0fcf58f2b4faf37893ef9d97cddde699/selenium-3.14.1-py2.py3-none-any.whl (902kB)
# Requirement already satisfied: urllib3 in c:\users\jiangsir\anaconda3\lib\site-packages (from selenium) (1.22)
# Installing collected packages: selenium
# Successfully installed selenium-3.14.1
# You are using pip version 18.0, however version 18.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %% [markdown]
# # 下載瀏覽器控制器
#
#  [chromedriver.exe](files/chromedriver.exe)
#
#  將 chromedriver.exe 複製到 C:\\Users\\jiangsir\\Anaconda3\\  以便未來使用

# %%
## 找到使用的是哪一個 python

import sys
sys.executable
# Out:
# 'C:\\Users\\jiangsir\\Anaconda3\\python.exe'

# %% [markdown]
# # 見證神奇的時刻
#
# ### 你會見到瀏覽器自行打開，連到指定的網站，並且這個瀏覽器會顯示被自動測試程式控制。
#
# ![](images/Selenium.PNG)

# %%
from selenium import webdriver
# 打開瀏覽器
driver = webdriver.Chrome()

# 連到我想去的網站
driver.get("http://zerojudge.tw")

#關閉瀏覽器
#driver.close()

# %% [markdown]
# # 打開瀏覽器，連線到 google

# %%
from selenium import webdriver
from selenium.common.exceptions import TimeoutException
 
# available since 2.4.0
from selenium.webdriver.support.ui import WebDriverWait
 
# available since 2.26.0
from selenium.webdriver.support import expected_conditions as EC
 
# 建立 driver
# 需下載 Browser Drivers http://www.seleniumhq.org/download/ 
# 若 geckodriver 有在 PATH 中， firefox 可不帶路徑參數

# 打開瀏覽器
driver = webdriver.Chrome(executable_path="C:\\Users\\jiangsir\\Anaconda3\\chromedriver.exe")

# 去 google
driver.get("http://www.google.com")
 
# 顯示標題
print(driver.title)

# 關閉瀏覽器
driver.close()
# Out:
# Google

# %% [markdown]
# # 單一條件查詢

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import NoAlertPresentException
import unittest, time, re
import requests
import pandas as pd

# executable_path="C:\\Users\\jiangsir\\Anaconda3\\chromedriver.exe"

driver = webdriver.Chrome()
driver.implicitly_wait(30)
verificationErrors = []
accept_next_alert = True

driver.get("https://www4.inservice.edu.tw/NAPP/OpenQuery.aspx")
driver.find_element_by_id("ctl00_CPH_Content_RTB_CourseName").click()
driver.find_element_by_id("ctl00_CPH_Content_RTB_CourseName").clear()
driver.find_element_by_id("ctl00_CPH_Content_RTB_CourseName").send_keys("人工智慧")
driver.find_element_by_xpath("(.//*[normalize-space(text()) and normalize-space(.)='顯示更多方式'])[1]/following::span[1]").click()
element = driver.find_element_by_xpath('//*[@id="ctl00_CPH_Content_RG_SearchResult_ctl00"]')
html = element.get_attribute('outerHTML')
df = pd.read_html(html)
driver.close()
df[0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-15007ed2bc75> in <module>()
#      17
#      18 driver.get("https://www4.inservice.edu.tw/NAPP/OpenQuery.aspx")
# ---> 19 driver.find_element_by_id("ctl00_CPH_Content_RTB_CourseName").click()
#      20 driver.find_element_by_id("ctl00_CPH_Content_RTB_CourseName").clear()
#      21 driver.find_element_by_id("ctl00_CPH_Content_RTB_CourseName").send_keys("人工智慧")
#
# AttributeError: 'NoneType' object has no attribute 'click'

# %% [markdown]
# # 多條件查詢

# %%
import time, os
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import NoAlertPresentException
import unittest, time, re
import requests
import pandas as pd
import smtplib
from email.mime.text import MIMEText

def query(driver, keyword):
    driver.get("https://www4.inservice.edu.tw/NAPP/OpenQuery.aspx")
    driver.find_element_by_id("ctl00_CPH_Content_RTB_CourseName").click()
    driver.find_element_by_id("ctl00_CPH_Content_RTB_CourseName").clear()
    driver.find_element_by_id("ctl00_CPH_Content_RTB_CourseName").send_keys(keyword)
    driver.find_element_by_xpath("(.//*[normalize-space(text()) and normalize-space(.)='顯示更多方式'])[1]/following::span[1]").click()
    element = driver.find_element_by_xpath('//*[@id="ctl00_CPH_Content_RG_SearchResult_ctl00"]')
    html = element.get_attribute('outerHTML')
    return pd.read_html(html)

# executable_path="C:\\Users\\jiangsir\\Anaconda3\\chromedriver.exe"
driver = webdriver.Chrome()

driver.implicitly_wait(30)
verificationErrors = []
accept_next_alert = True

keywords = ["人工智慧", "物聯網", "大數據"]

df = pd.DataFrame()
for keyword in keywords:
    df1 = query(driver, keyword)
    if df.empty:
        df = df1[0]
    else:
        df = pd.concat([df, df1[0]])

#driver.close()
driver.quit()

df
# Out:
#                                       課程代碼  \
# 0                                  2611218
# 1                                  2587435
# 2                                  2615610
# 3                                  2621439
# 4                                  2561041
# 5     1  每頁筆數：  select  5 items in 1 pages
# 0                                  2604501
# 1                                  2608404
# 2                                  2612899
# 3                                  2594808
# 4                                  2598363
# 5                                  2598415
# 6                                  2606874
# 7                                  2598420
# 8                                  2612900
# 9                                  2581140
# 10  12  每頁筆數：  select  19 items in 2 pages
# 0                                  2587435
# 1                                  2583070
# 2                                  2581140
# 3                                  2608947
# 4     1  每頁筆數：  select  4 items in 1 pages
#
#                                                  研習名稱        開始日期        結束日期  \
# 0                  108年春季分享大師視野講座：我的醫生是機器人─人工智慧Watson  2019/04/26  2019/04/26
# 1                      縣級「新興科技」教師增能工作坊-AI人工智慧大數據(場次二)  2019/04/27  2019/06/15
# 2                               AI人工智慧語音控制與智慧小車(生活科技)  2019/04/30  2019/04/30
# 3                           「人工智慧咖啡GO：水、火、風、土、氣與咖啡晶球」  2019/05/08  2019/05/08
# 4                                           人工智慧教育的改變  2019/05/22  2019/05/22
# 5                                                 NaN         NaN         NaN
# 0                       IoT物聯網資訊應用-Webduino教學實務工作坊(二)  2019/04/26  2019/04/26
# 1                       NKNUScratch3.0＋電動車+物聯網衛星基地認證班  2019/04/27  2019/04/27
# 2                                  第四梯次：智慧物聯網的認識與應用研習  2019/04/29  2019/04/29
# 3   高雄市自造教育及科技中心 自造教育課程研發與推廣系列課程教師培訓 WebBit與物聯網教師研...  2019/05/02  2019/05/02
# 4                             程式控制發展社群分享講座(物聯網運用融入教學)  2019/05/03  2019/05/03
# 5                              Webduino 與物聯網教學活動-基礎研習  2019/05/07  2019/05/07
# 6                          「Python程式在物聯網的應用 」教師專業成長研習  2019/05/08  2019/05/08
# 7                              Webduino 與物聯網教學活動-進階研習  2019/05/10  2019/05/10
# 8                                  第五梯次：智慧物聯網的認識與應用研習  2019/05/10  2019/05/10
# 9          臺中女中數位學習深耕計畫－主題跨域課程推廣研習～物聯網環境品質偵測器實作與大數據分析  2019/05/14  2019/05/14
# 10                                                NaN         NaN         NaN
# 0                      縣級「新興科技」教師增能工作坊-AI人工智慧大數據(場次二)  2019/04/27  2019/06/15
# 1                        108年春季分享大師視野講座：從醫療大數據談臺灣公共衛生  2019/05/03  2019/05/03
# 2          臺中女中數位學習深耕計畫－主題跨域課程推廣研習～物聯網環境品質偵測器實作與大數據分析  2019/05/14  2019/05/14
# 3                               [素養導向]大數據時代的國家治理與企業經營  2019/06/13  2019/06/13
# 4                                                 NaN         NaN         NaN
#
#             辦理研習單位                                                 列表
# 0   臺中市  國立自然科學博物館  26112182019/04/26~ 2019/04/26  108年春季分享大師視野講座：...
# 1      彰化縣  縣立花壇國中  25874352019/04/27~ 2019/06/15  縣級「新興科技」教師增能工作坊...
# 2      臺中市  私立明道高中  26156102019/04/30~ 2019/04/30  AI人工智慧語音控制與智慧小車...
# 3      臺南市  國立臺南女中  26214392019/05/08~ 2019/05/08  「人工智慧咖啡GO：水、火、風...
# 4      臺中市  市立仁美國小  25610412019/05/22~ 2019/05/22  人工智慧教育的改變  臺中市｜...
# 5              NaN                                                NaN
# 0      新竹縣  縣立東興國小  26045012019/04/26~ 2019/04/26  IoT物聯網資訊應用-Webd...
# 1    高雄市  國立高雄師範大學  26084042019/04/27~ 2019/04/27  NKNUScratch3.0＋...
# 2      南投縣  縣立康壽國小  26128992019/04/29~ 2019/04/29  第四梯次：智慧物聯網的認識與應...
# 3      高雄市  市立中山國中  25948082019/05/02~ 2019/05/02  高雄市自造教育及科技中心 自造...
# 4      基隆市  私立二信高中  25983632019/05/03~ 2019/05/03  程式控制發展社群分享講座(物聯...
# 5      臺中市  市立僑仁國小  25984152019/05/07~ 2019/05/07  Webduino 與物聯網教學...
# 6      臺南市  國立臺南高商  26068742019/05/08~ 2019/05/08  「Python程式在物聯網的應...
# 7      臺中市  市立僑仁國小  25984202019/05/10~ 2019/05/10  Webduino 與物聯網教學...
# 8      南投縣  縣立康壽國小  26129002019/05/10~ 2019/05/10  第五梯次：智慧物聯網的認識與應...
# 9      臺中市  市立臺中女中  25811402019/05/14~ 2019/05/14  臺中女中數位學習深耕計畫－主題...
# 10             NaN                                                NaN
# 0      彰化縣  縣立花壇國中  25874352019/04/27~ 2019/06/15  縣級「新興科技」教師增能工作坊...
# 1   臺中市  國立自然科學博物館  25830702019/05/03~ 2019/05/03  108年春季分享大師視野講座：...
# 2      臺中市  市立臺中女中  25811402019/05/14~ 2019/05/14  臺中女中數位學習深耕計畫－主題...
# 3      新北市  市立板橋高中  26089472019/06/13~ 2019/06/13  [素養導向]大數據時代的國家治...
# 4              NaN                                                NaN

# %% [markdown]
# # 將查到的資訊合併，取聯集

# %%
import time, os
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import NoAlertPresentException
import unittest, time, re
import requests
import pandas as pd
import smtplib
from email.mime.text import MIMEText

def query(driver, keyword):
    driver.get("https://www4.inservice.edu.tw/NAPP/OpenQuery.aspx")
    driver.find_element_by_id("ctl00_CPH_Content_RTB_CourseName").click()
    driver.find_element_by_id("ctl00_CPH_Content_RTB_CourseName").clear()
    driver.find_element_by_id("ctl00_CPH_Content_RTB_CourseName").send_keys(keyword)
    driver.find_element_by_xpath("(.//*[normalize-space(text()) and normalize-space(.)='顯示更多方式'])[1]/following::span[1]").click()
    element = driver.find_element_by_xpath('//*[@id="ctl00_CPH_Content_RG_SearchResult_ctl00"]')
    html = element.get_attribute('outerHTML')
    df_html = pd.read_html(html)[0]
    df_html.drop(df_html.tail(1).index, inplace=True) 
    return df_html

# executable_path="C:\\Users\\jiangsir\\Anaconda3\\chromedriver.exe"
driver = webdriver.Chrome()

driver.implicitly_wait(30)
verificationErrors = []
accept_next_alert = True

keywords = ["人工智慧", "物聯網", "大數據"]

df = pd.DataFrame()

for keyword in keywords:
    df1 = query(driver, keyword)
    if df.empty:
        df = df1
    else:
        df = pd.concat([df, df1])

#driver.close()
driver.quit()


df = df.drop_duplicates(['課程代碼'])
df = df.sort_values(['開始日期'],ascending=[1])
df
# Out:
#       課程代碼                                               研習名稱        開始日期  \
# 0  2587435                     縣級「新興科技」教師增能工作坊-AI人工智慧大數據(場次二)  2019/04/27
# 0  2608404                      NKNUScratch3.0＋電動車+物聯網衛星基地認證班  2019/04/27
# 1  2612899                                 第四梯次：智慧物聯網的認識與應用研習  2019/04/29
# 1  2615610                              AI人工智慧語音控制與智慧小車(生活科技)  2019/04/30
# 2  2594808  高雄市自造教育及科技中心 自造教育課程研發與推廣系列課程教師培訓 WebBit與物聯網教師研...  2019/05/02
# 3  2598363                            程式控制發展社群分享講座(物聯網運用融入教學)  2019/05/03
# 1  2583070                       108年春季分享大師視野講座：從醫療大數據談臺灣公共衛生  2019/05/03
# 4  2598415                             Webduino 與物聯網教學活動-基礎研習  2019/05/07
# 2  2621439                          「人工智慧咖啡GO：水、火、風、土、氣與咖啡晶球」  2019/05/08
# 5  2606874                         「Python程式在物聯網的應用 」教師專業成長研習  2019/05/08
# 6  2598420                             Webduino 與物聯網教學活動-進階研習  2019/05/10
# 7  2612900                                 第五梯次：智慧物聯網的認識與應用研習  2019/05/10
# 8  2581140         臺中女中數位學習深耕計畫－主題跨域課程推廣研習～物聯網環境品質偵測器實作與大數據分析  2019/05/14
# 9  2560029                            物聯網Webduino創意智慧家庭實作班第一期  2019/05/18
# 3  2561041                                          人工智慧教育的改變  2019/05/22
# 3  2608947                              [素養導向]大數據時代的國家治理與企業經營  2019/06/13
#
#          結束日期          辦理研習單位  \
# 0  2019/06/15     彰化縣  縣立花壇國中
# 0  2019/04/27   高雄市  國立高雄師範大學
# 1  2019/04/29     南投縣  縣立康壽國小
# 1  2019/04/30     臺中市  私立明道高中
# 2  2019/05/02     高雄市  市立中山國中
# 3  2019/05/03     基隆市  私立二信高中
# 1  2019/05/03  臺中市  國立自然科學博物館
# 4  2019/05/07     臺中市  市立僑仁國小
# 2  2019/05/08     臺南市  國立臺南女中
# 5  2019/05/08     臺南市  國立臺南高商
# 6  2019/05/10     臺中市  市立僑仁國小
# 7  2019/05/10     南投縣  縣立康壽國小
# 8  2019/05/14     臺中市  市立臺中女中
# 9  2019/06/22     高雄市  國立高雄大學
# 3  2019/05/22     臺中市  市立仁美國小
# 3  2019/06/13     新北市  市立板橋高中
#
#                                                   列表
# 0  25874352019/04/27~ 2019/06/15  縣級「新興科技」教師增能工作坊...
# 0  26084042019/04/27~ 2019/04/27  NKNUScratch3.0＋...
# 1  26128992019/04/29~ 2019/04/29  第四梯次：智慧物聯網的認識與應...
# 1  26156102019/04/30~ 2019/04/30  AI人工智慧語音控制與智慧小車...
# 2  25948082019/05/02~ 2019/05/02  高雄市自造教育及科技中心 自造...
# 3  25983632019/05/03~ 2019/05/03  程式控制發展社群分享講座(物聯...
# 1  25830702019/05/03~ 2019/05/03  108年春季分享大師視野講座：...
# 4  25984152019/05/07~ 2019/05/07  Webduino 與物聯網教學...
# 2  26214392019/05/08~ 2019/05/08  「人工智慧咖啡GO：水、火、風...
# 5  26068742019/05/08~ 2019/05/08  「Python程式在物聯網的應...
# 6  25984202019/05/10~ 2019/05/10  Webduino 與物聯網教學...
# 7  26129002019/05/10~ 2019/05/10  第五梯次：智慧物聯網的認識與應...
# 8  25811402019/05/14~ 2019/05/14  臺中女中數位學習深耕計畫－主題...
# 9  25600292019/05/18~ 2019/06/22  物聯網Webduino創意智慧...
# 3  25610412019/05/22~ 2019/05/22  人工智慧教育的改變  臺中市｜...
# 3  26089472019/06/13~ 2019/06/13  [素養導向]大數據時代的國家治...

# %% [markdown]
# # 判斷哪些是新增的研習
#
# ### 希望能夠清楚列出本次搜尋所發現的新增研習並且通知，會更友善。
# ### 那就必須把上一次的搜尋結果記錄下來以便下一次比對。由於資料量小，不需要動用到資料庫，直接以 CSV 儲存 即可。

# %%
import time, os
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import NoAlertPresentException
import unittest, time, re
import requests
import pandas as pd
import smtplib
from email.mime.text import MIMEText

def query(driver, keyword):
    driver.get("https://www4.inservice.edu.tw/NAPP/OpenQuery.aspx")
    driver.find_element_by_id("ctl00_CPH_Content_RTB_CourseName").click()
    driver.find_element_by_id("ctl00_CPH_Content_RTB_CourseName").clear()
    driver.find_element_by_id("ctl00_CPH_Content_RTB_CourseName").send_keys(keyword)
    driver.find_element_by_xpath("(.//*[normalize-space(text()) and normalize-space(.)='顯示更多方式'])[1]/following::span[1]").click()
    element = driver.find_element_by_xpath('//*[@id="ctl00_CPH_Content_RG_SearchResult_ctl00"]')
    html = element.get_attribute('outerHTML')
    df_html = pd.read_html(html)[0]
    df_html.drop(df_html.tail(1).index, inplace=True) 
    return df_html

# executable_path="C:\\Users\\jiangsir\\Anaconda3\\chromedriver.exe"
driver = webdriver.Chrome()

driver.implicitly_wait(30)
verificationErrors = []
accept_next_alert = True

keywords = ["人工智慧", "物聯網", "大數據"]

df = pd.DataFrame()

for keyword in keywords:
    df1 = query(driver, keyword)
    if df.empty:
        df = df1
    else:
        df = pd.concat([df, df1])

#driver.close()
driver.quit()


df = df.drop_duplicates(['課程代碼'])
df = df.sort_values(['開始日期'],ascending=[1])

df.to_csv('TeacherCourses.csv')
df
# Out:
#       課程代碼                                               研習名稱        開始日期  \
# 0  2587435                     縣級「新興科技」教師增能工作坊-AI人工智慧大數據(場次二)  2019/04/27
# 0  2608404                      NKNUScratch3.0＋電動車+物聯網衛星基地認證班  2019/04/27
# 1  2612899                                 第四梯次：智慧物聯網的認識與應用研習  2019/04/29
# 1  2615610                              AI人工智慧語音控制與智慧小車(生活科技)  2019/04/30
# 2  2594808  高雄市自造教育及科技中心 自造教育課程研發與推廣系列課程教師培訓 WebBit與物聯網教師研...  2019/05/02
# 3  2598363                            程式控制發展社群分享講座(物聯網運用融入教學)  2019/05/03
# 1  2583070                       108年春季分享大師視野講座：從醫療大數據談臺灣公共衛生  2019/05/03
# 4  2598415                             Webduino 與物聯網教學活動-基礎研習  2019/05/07
# 2  2621439                          「人工智慧咖啡GO：水、火、風、土、氣與咖啡晶球」  2019/05/08
# 5  2606874                         「Python程式在物聯網的應用 」教師專業成長研習  2019/05/08
# 6  2598420                             Webduino 與物聯網教學活動-進階研習  2019/05/10
# 7  2612900                                 第五梯次：智慧物聯網的認識與應用研習  2019/05/10
# 8  2581140         臺中女中數位學習深耕計畫－主題跨域課程推廣研習～物聯網環境品質偵測器實作與大數據分析  2019/05/14
# 9  2560029                            物聯網Webduino創意智慧家庭實作班第一期  2019/05/18
# 3  2561041                                          人工智慧教育的改變  2019/05/22
# 3  2608947                              [素養導向]大數據時代的國家治理與企業經營  2019/06/13
#
#          結束日期          辦理研習單位  \
# 0  2019/06/15     彰化縣  縣立花壇國中
# 0  2019/04/27   高雄市  國立高雄師範大學
# 1  2019/04/29     南投縣  縣立康壽國小
# 1  2019/04/30     臺中市  私立明道高中
# 2  2019/05/02     高雄市  市立中山國中
# 3  2019/05/03     基隆市  私立二信高中
# 1  2019/05/03  臺中市  國立自然科學博物館
# 4  2019/05/07     臺中市  市立僑仁國小
# 2  2019/05/08     臺南市  國立臺南女中
# 5  2019/05/08     臺南市  國立臺南高商
# 6  2019/05/10     臺中市  市立僑仁國小
# 7  2019/05/10     南投縣  縣立康壽國小
# 8  2019/05/14     臺中市  市立臺中女中
# 9  2019/06/22     高雄市  國立高雄大學
# 3  2019/05/22     臺中市  市立仁美國小
# 3  2019/06/13     新北市  市立板橋高中
#
#                                                   列表
# 0  25874352019/04/27~ 2019/06/15  縣級「新興科技」教師增能工作坊...
# 0  26084042019/04/27~ 2019/04/27  NKNUScratch3.0＋...
# 1  26128992019/04/29~ 2019/04/29  第四梯次：智慧物聯網的認識與應...
# 1  26156102019/04/30~ 2019/04/30  AI人工智慧語音控制與智慧小車...
# 2  25948082019/05/02~ 2019/05/02  高雄市自造教育及科技中心 自造...
# 3  25983632019/05/03~ 2019/05/03  程式控制發展社群分享講座(物聯...
# 1  25830702019/05/03~ 2019/05/03  108年春季分享大師視野講座：...
# 4  25984152019/05/07~ 2019/05/07  Webduino 與物聯網教學...
# 2  26214392019/05/08~ 2019/05/08  「人工智慧咖啡GO：水、火、風...
# 5  26068742019/05/08~ 2019/05/08  「Python程式在物聯網的應...
# 6  25984202019/05/10~ 2019/05/10  Webduino 與物聯網教學...
# 7  26129002019/05/10~ 2019/05/10  第五梯次：智慧物聯網的認識與應...
# 8  25811402019/05/14~ 2019/05/14  臺中女中數位學習深耕計畫－主題...
# 9  25600292019/05/18~ 2019/06/22  物聯網Webduino創意智慧...
# 3  25610412019/05/22~ 2019/05/22  人工智慧教育的改變  臺中市｜...
# 3  26089472019/06/13~ 2019/06/13  [素養導向]大數據時代的國家治...

# %% [markdown]
# # 把査到的資訊寄信給自己
#
# 以下為 mailer.py 程式，可放入排程，讓 windows 定時執行。

# %%
import time, os
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import NoAlertPresentException
import unittest, time, re
import requests
import pandas as pd
import smtplib
from email.mime.text import MIMEText




def mailer(subject, html, mailto='jiangzero@gmail.com', mailfrom='jiangsir@tea.nknush.kh.edu.tw', passwd='igajmuqzhnhuyzil'):
    mime=MIMEText(html, "html", "utf-8")
    mime["Subject"]=subject
    mime["From"]="教師研習自動通知"
    mime["To"]=""
    msg=mime.as_string()

    smtpssl=smtplib.SMTP_SSL("smtp.gmail.com", 465) 
    smtpssl.ehlo()
    smtpssl.login(mailfrom, passwd)

    to_addr=[mailto]
    status=smtpssl.sendmail(mailfrom, to_addr, msg)
    if status=={}:
        print("郵件傳送成功!")
    else:
        print("郵件傳送失敗!")
    smtpssl.quit()    

def query(driver, keyword):
    driver.get("https://www4.inservice.edu.tw/NAPP/OpenQuery.aspx")
    driver.find_element_by_id("ctl00_CPH_Content_RTB_CourseName").click()
    driver.find_element_by_id("ctl00_CPH_Content_RTB_CourseName").clear()
    driver.find_element_by_id("ctl00_CPH_Content_RTB_CourseName").send_keys(keyword)
    driver.find_element_by_xpath("(.//*[normalize-space(text()) and normalize-space(.)='顯示更多方式'])[1]/following::span[1]").click()
    element = driver.find_element_by_xpath('//*[@id="ctl00_CPH_Content_RG_SearchResult_ctl00"]')
    html = element.get_attribute('outerHTML')
    df_html = pd.read_html(html)[0]
    df_html.drop(df_html.tail(1).index, inplace=True) 
    return df_html

driver = webdriver.Chrome()
driver.implicitly_wait(30)
verificationErrors = []
accept_next_alert = True

keywords = ["人工智慧", "物聯網", "大數據"]

df = pd.DataFrame()
for keyword in keywords:
    df1 = query(driver, keyword)
    if df.empty:
        df = df1
    else:
        df = pd.concat([df, df1])
#driver.close()
driver.quit()

df = df.drop_duplicates(['課程代碼'])
df = df.sort_values(['開始日期'],ascending=[1])

mailer("教師研習網篩選通知("+str(keywords)+")", df.to_html())
# Out:
# 郵件傳送成功!
